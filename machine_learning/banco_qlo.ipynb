# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\cetecom\Desktop\Monopoly.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Id  Subsegmento Sexo  Region  Edad     Renta  Antiguedad  \
# 0           0   1          160    M    13.0    43       NaN         130
# 1           1   2          160    H    13.0    46  143640.0          69
# 2           2   3          170    H    13.0    45  929106.0          24
# 3           3   4          151    H    13.0    46  172447.0         134
# 4           4   5          170    H    13.0    46  805250.0         116
#
#    Internauta  Adicional  ...  PagoNac_T01  PagoInt_T01  EeccNac_T01  \
# 0           1          1  ...        33000          0.0    1099866.0
# 1           1          0  ...       300000          0.0     214592.0
# 2           1          1  ...       216676          0.0          0.0
# 3           0          1  ...        60000          0.0     272762.0
# 4           0          1  ...       272925          0.0     249562.0
#
#    EeccInt_T01  UsoL1_T01  UsoL2_T01  UsoLI_T01  IndRev_T01  target  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'Subsegmento', 'Sexo', 'Region', 'Edad', 'Renta',
#        'Antiguedad', 'Internauta', 'Adicional',
#        ...
#        'PagoNac_T01', 'PagoInt_T01', 'EeccNac_T01', 'EeccInt_T01', 'UsoL1_T01',
#        'UsoL2_T01', 'UsoLI_T01', 'IndRev_T01', 'target', 'Unnamed: 574'],
#       dtype='object', length=576)

# %%
df['Renta']
# Out:
# 0             NaN
# 1        143640.0
# 2        929106.0
# 3        172447.0
# 4        805250.0
#            ...
# 51119    364978.0
# 51120    625376.0
# 51121    806220.0
# 51122         NaN
# 51123    840878.0
# Name: Renta, Length: 51124, dtype: float64

# %%
df[df['Renta'] < 460000]
# Out:
#        Unnamed: 0     Id  Subsegmento Sexo  Region  Edad     Renta  \
# 1               1      2          160    H    13.0    46  143640.0
# 3               3      4          151    H    13.0    46  172447.0
# 18             18     19          170    M    13.0    47  176712.0
# 19             19     20          160    M     8.0    46  210298.0
# 23             23     24          170    H    13.0    46  440339.0
# ...           ...    ...          ...  ...     ...   ...       ...
# 51109       51109  51110          151    H    13.0    49  150000.0
# 51113       51113  51114          160    M     5.0    49  400000.0
# 51114       51114  51115          170    M    13.0    47  229938.0
# 51118       51118  51119          160    M    13.0    44  414316.0
# 51119       51119  51120          160    H    13.0    51  364978.0
#
#        Antiguedad  Internauta  Adicional  ...  PagoNac_T01  PagoInt_T01  \
# 1              69           1          0  ...       300000          0.0
# ...

# %%
51123-12334
# Out:
# 38789

# %%
df = df.dropna(subset=['Renta'])
df = df.dropna(subset=['Region'])
df = df.dropna(subset=['Sexo'])
df = df.dropna(subset=['Subsegmento'])
df = df.dropna(subset=['Edad'])
df = df.dropna(subset=['Antiguedad'])
df = df.dropna(subset=['Consumo'])
df = df.dropna(subset=['Hipotecario'])
df = df.dropna(subset=['Renta'])
df = df.dropna(subset=['Renta'])
df = df.dropna(subset=['Renta'])


df['Renta']
# Out:
# 1        143640.0
# 2        929106.0
# 3        172447.0
# 4        805250.0
# 5        707664.0
#            ...
# 51118    414316.0
# 51119    364978.0
# 51120    625376.0
# 51121    806220.0
# 51123    840878.0
# Name: Renta, Length: 37759, dtype: float64

# %%
df.loc[df['Renta'] < 460000, 'Renta'] = 460000

df['Renta']
# Out:
# 0             NaN
# 1        460000.0
# 2        929106.0
# 3        460000.0
# 4        805250.0
#            ...
# 51119    460000.0
# 51120    625376.0
# 51121    806220.0
# 51122         NaN
# 51123    840878.0
# Name: Renta, Length: 51124, dtype: float64
